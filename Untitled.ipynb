# %%
import nltk
import spacy
from collections import Counter
from database.pymysql_conn import DataBase
from tqdm import tqdm
from gensim.parsing.preprocessing import remove_stopwords
from pattern.text.en import singularize
import pandas as pd

import pickle

tqdm.pandas()

# %%
db = DataBase()

# %%
SQL="""
SELECT 
    T1.appid,
    T1.avg_player_count,
    T1.gameName,
    T1.release_date,
    T2.publishedAt,
    T2.text,    
    DATEDIFF(T2.publishedAt, T1.release_date) as datediff
FROM
    (SELECT 
        A.appid, A.gameName, A.avg_player_count, B.release_date
    FROM
        (SELECT 
        *
    FROM
        yt.games) A
    JOIN (SELECT 
        appid, name, MAX(release_date) AS release_date
    FROM
        oasis.app_info2
    GROUP BY appid) AS B ON A.appid = B.appid) T1
        LEFT JOIN
    (SELECT 
        appid, gameName, text, publishedAt
    FROM
        steam.yt_comment
    WHERE
        filter = 0 AND language = 'en') T2 ON T1.appid = T2.appid
WHERE
    DATEDIFF(T2.publishedAt, T1.release_date) <= 300
"""

# %%
df = db.to_df(SQL)

# %%
success = ["Dota Underlords",
            "Borderlands GOTY Enhanced",
            "Anno 1800",
            "F1 2019",
            "DEAD OR ALIVE Xtreme Venus Vacation",
            "RAGE 2",
            "OCTOPATH TRAVELER",
            "Lords Mobile",
            "Pro Cycling Manager 2019",
            "Ironsight",
            "Yakuza Kiwami 2", # 10
            "Pagan Online",
            "Monster Girl Island Prologue",
            "Winning Post 9",
            "Assassins Creed III Remastered",
            "Otakus Adventure",
            "SUPER DRAGON BALL HEROES WORLD MISSION",
            "AVA Dog Tag"] # 500++

# %%
df_success = df[df['gameName'].isin(success)]
df_fail = df[~df['gameName'].isin(success)]

# %%
# 성공게임 출시전 댓글
groupA = df_success[df_success['datediff'] < 0]
# 성공게임 출시후 댓글
groupB = df_success[df_success['datediff'] >= 0]
# 보통게임 출시후 댓글
groupC = df_fail[df_fail['datediff'] >=0]

# %%
# for Pandas
def normalize_text(text):
    text = text.str.lower() # lowercase
    text = text.str.replace(r"\#","") # replaces hashtags
    text = text.str.replace(r"http\S+","URL")  # remove URL addresses
    text = text.str.replace(r"[^A-Za-z0-9()!?\'\`\"]", " ")
    text = text.str.replace("\s{2,}", " ")
    return text

# %%
def text_cleaning_pipeline(df):
    text = df['text']
    text = normalize_text(text)

# %%
spacy_en = spacy.load("en")

def tokenize(text):
    # text = normalize_text(text)
    # text = remove_stopwords(text)
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
def token_singularize(tokens):
    return [singularize(x) for x in tokens]

# %%
def remove_single_word(tokens):
    return [x for x in tokens if len(x) > 1]

# %%
is_noun = lambda pos: 'NN' in pos[:2]
is_adj = lambda pos: 'JJ' in pos[:2]
is_verb = lambda pos: 'VB' in pos[:2]

def pos_tagging(text, func):
    tokenized = tokenize(text)
    pos = [word for (word, pos) in nltk.pos_tag(tokenized) if func(pos)] 
    return pos

# %%
def pos_tagging_test(text, func):
    # tokenized = nltk.word_tokenize(text)
    tokenized = tokenize(text)
    
    pos = [(word, pos) for (word, pos) in nltk.pos_tag(tokenized) if func(pos)] 
    return pos

# %%
def get_counts(df, func):
    
    pos = df['text'].progress_apply(pos_tagging, args=(func,))
    unpacked = [word for sent in pos for word in sent]
    cnt = Counter(unpacked)
    return cnt

# %% [markdown]
# # TEST

# %%
test_group = groupA[:100]

# %%
test_input = normalize_text(test_group['text'])
pos = test_input.progress_apply(pos_tagging, args=(is_noun,))
# Out:
# 100%|██████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 364.88it/s]

# %%
pos = pos.progress_apply(token_singularize)
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 6665.24it/s]

# %%
pos = pos.progress_apply(remove_single_word)
# Out:
# 100%|████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 99983.41it/s]

# %%
unpacked = [word for sent in pos for word in sent]

# %%
test_group['token'] = pos
# Out:
# C:\ProgramData\Anaconda3\envs\pytorch-gpu-V\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_group
# Out:
#       appid  avg_player_count                             gameName  \
# 47   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 48   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 49   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 50   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 51   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 52   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 53   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 54   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 55   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 56   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 57   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 58   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 59   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 60   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 61   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 62   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 63   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 64   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 65   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 66   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 67   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 68   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 69   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 70   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 71   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 72   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 73   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 74   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 75   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 76   958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# ..      ...               ...                                  ...
# 117  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 118  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 119  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 120  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 121  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 122  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 123  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 124  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 125  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 126  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 127  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 128  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 129  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 130  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 131  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 132  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 133  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 134  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 135  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 136  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 137  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 138  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 139  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 140  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 141  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 142  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 143  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 144  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 145  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
# 146  958260         2151.9409  DEAD OR ALIVE Xtreme Venus Vacation
#
#     release_date         publishedAt  \
# 47    2019-03-26 2019-02-10 05:30:53
# 48    2019-03-26 2018-12-26 19:25:53
# 49    2019-03-26 2018-11-15 23:00:43
# 50    2019-03-26 2018-11-10 17:58:37
# 51    2019-03-26 2018-10-25 17:13:17
# 52    2019-03-26 2018-10-18 16:58:47
# 53    2019-03-26 2018-10-15 22:07:08
# 54    2019-03-26 2018-10-12 12:38:57
# 55    2019-03-26 2018-10-10 12:55:07
# 56    2019-03-26 2018-10-08 03:47:56
# 57    2019-03-26 2018-10-05 19:41:31
# 58    2019-03-26 2018-10-01 17:34:36
# 59    2019-03-26 2018-10-01 08:36:53
# 60    2019-03-26 2018-09-15 14:51:01
# 61    2019-03-26 2018-09-13 12:48:10
# 62    2019-03-26 2018-09-08 05:02:59
# 63    2019-03-26 2018-09-05 19:53:57
# 64    2019-03-26 2018-08-22 03:53:27
# 65    2019-03-26 2018-08-19 19:30:27
# 66    2019-03-26 2018-08-15 00:16:03
# 67    2019-03-26 2018-08-11 17:34:58
# 68    2019-03-26 2018-08-01 13:13:24
# 69    2019-03-26 2018-07-31 17:35:15
# 70    2019-03-26 2018-07-30 21:50:44
# 71    2019-03-26 2018-07-30 06:33:21
# 72    2019-03-26 2018-07-29 14:32:16
# 73    2019-03-26 2018-07-25 06:31:33
# 74    2019-03-26 2018-07-21 05:15:19
# 75    2019-03-26 2018-07-20 07:26:09
# 76    2019-03-26 2018-07-17 18:49:11
# ..           ...                 ...
# 117   2019-03-26 2018-05-20 02:29:17
# 118   2019-03-26 2018-05-19 14:19:36
# 120  I wish there were a game with Ai-Chan starring...      -311
# 121          Truly, the pinnacle of video game design.      -311
# 122    I think I’m in love with kizuna already lol. ❤️      -311
# 123  This is so meta, the new girl is named Luna wh...      -311
# 124                 Please try "Getting Over It" game!      -311
# 125                             the best waifu channel      -311
# 126                       Dear translators... Enjoy xD      -311
# 127  I want her to play Kirby Star Allies.  Suggest...      -311
# 128                      gonna bet Ai chan fap to this      -311
# 129  *stare~* (⁄ ⁄o⁄ω⁄o⁄ ⁄) Kizuna, I do not think ...      -311
# 130  Ai-chan has succumbed to *this* game ooooh boi...      -312
# 131                             two words: live stream      -312
# 132                      Where's the English captions?      -312
# 133                  Ai-Chan's thirsty as usual kkkkkk      -312
# 134      5:22 ZA WARUDO! 時を止まれ！   ...what? ( ͡° ͜ʖ ͡°)      -312
# 135        Ah, I see you are an AI of culture as well.      -312
# 136      guess ai-chan's yet to discover her sexuality      -312
# 137       If ai chan has a brother and play this game?      -312
# 138                       Luna voiced by Yua     Nani?      -312
# 139  so how do we know that this is actually an A.I...      -312
# 140   Try not to drool into the mic too much, Ai-chan.      -312
# 141       R-18 Gone Sexual episode ever !!! Very Goodo      -312
# 142  first ever demonetized video? great... Ai chan...      -312
# 143                     4:45 she touched her boobs lol      -312
# 144  6:27 Ai chans face looks like lenny face ( ͡° ...      -312
# 145  Need a kawaii counter so I can tell the doctor...      -312
# 146  how could you already get soo many (not just s...      -312
#
#                                                  token
# 47                                       [ai, culture]
# 48                                    [perv, ai, chan]
# 49                                              [year]
# 50                           [japanese, boob, as, way]
# 51         [cute, girl, girl, cuter, man, man, unfair]
# 52                                     [marie, cutest]
# 53                          [ai, chan, predator, face]
# 54                        [time, subtitle, eye, tiddy]
# 55                  [illusion, ero, game, stuff, lewd]
# 56                                     [boop, channel]
# 57                                              [game]
# 58                                  [thing, intensity]
# 59                                             [tiddy]
# 60                                       [time, kawai]
# 61                                   [chan, game, fun]
# 62                              [way, hand, girl, bet]
# 63                                  [cute, doesn, bit]
# 64                                                  []
# 65                                  [proof, chan, guy]
# 66                               [waifu, cute, kizuna]
# 67                                        [ai, honoka]
# 68                                  [xtreme, vacation]
# 69   [drinking, game, shot, time, kizuna, kawaius, ...
# 70                                       [lot, ochaco]
# 71                     [moment, ai, chan, playing, xd]
# 72                  [asium, version, game, ps4, vitum]
# 73                                               [top]
# 74                                                  []
# 75                                                [ai]
# 76                            [kizuna, man, man, trap]
# ..                                                 ...
# 117                                          [someone]
# 118                                 [way, rng, savage]
# 119                                                 []
# 120                                       [game, chan]
# 121                           [pinnacle, game, design]
# 122                                     [love, kizuna]
# 123         [girl, luna, youtuber, friend, chan, luna]
# 124                                             [game]
# 125                                   [waifu, channel]
# 126                                   [translator, xd]
# 127                                  [star, ally, yay]
# 128                                   [gon, chan, fap]
# 129                     [stare, kizuna, kawaius, word]
# 130                   [ai, chan, game, lol, room, heh]
# 131                                     [word, stream]
# 132                                          [caption]
# 133                        [ai, chan, thirsty, kkkkkk]
# 134                                       [za, warudo]
# 135                                  [ah, ai, culture]
# 136                            [gues, chan, sexuality]
# 137                              [chan, brother, game]
# 138                                  [luna, yua, nani]
# 139                                   [person, screen]
# 140                                    [try, ai, chan]
# 141                                          [episode]
# 142              [video, ai, chan, pewdiepie, example]
# 143                                        [boob, lol]
# 144                                   [ai, chan, face]
# 145                           [counter, doctor, liver]
# 146  [swimsuit, item, card, stage, everything, owne...
#
# [100 rows x 8 columns]

# %%
for group, groupName in zip((groupA[:10], groupB[:10], groupC[:10]), ("A", "B", "C")):
    print(groupName, "--------------------", flush=True)
    tokens=[]
    noun_tok = []
    adj_tok =[]
    verb_tok =[]
    for func, tag in zip((is_noun, is_adj, is_verb), ("Noun", "Adj", "Verb")):
        # 토큰화
        pos = group['text'].progress_apply(pos_tagging, args=(func,))
        # 단수화
        pos = pos.progress_apply(token_singularize)
        # 잘못된(1글자) 단어 제거
        pos = pos.progress_apply(remove_single_word)
        
        token = pos.to_list()
        
        # print(token)
        
        if tag == "Noun":
            noun_tok = token
        
        if tag == "Adj":
            adj_tok = token
        
        if tag == "Verb":
            verb_tok = token
    
    for a, b, c in zip(noun_tok, adj_tok, verb_tok):
        s = a + b + c
        tokens.append(s)
    
    print(len(tokens))
    
    group['token'] = tokens
# Out:
# A --------------------
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 526.39it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 3337.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 526.20it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 9995.96it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 9998.34it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 499.88it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 4997.38it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 9998.34it/s]
# 10
# B --------------------
# C:\ProgramData\Anaconda3\envs\pytorch-gpu-V\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 208.10it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 1999.67it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 9998.34it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 302.96it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 4999.17it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 302.97it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 2500.33it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<?, ?it/s]
# 10
# C --------------------
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 293.39it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 3333.05it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 9998.34it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 454.43it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 4997.98it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 454.45it/s]
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 4999.17it/s]
# 100%|██████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 10000.72it/s]
# 10

# %% [markdown]
# # df

# %%
for group, groupName in zip((groupA, groupB, groupC), ("A", "B", "C")):
    print(groupName, "--------------------", flush=True)
    tokens=[]
    noun_tok = []
    adj_tok =[]
    verb_tok =[]
    for func, tag in zip((is_noun, is_adj, is_verb), ("Noun", "Adj", "Verb")):
        # 토큰화
        pos = group['text'].progress_apply(pos_tagging, args=(func,))
        # 단수화
        pos = pos.progress_apply(token_singularize)
        # 잘못된(1글자) 단어 제거
        pos = pos.progress_apply(remove_single_word)
        
        token = pos.to_list()
        
        # print(token)
        
        if tag == "Noun":
            noun_tok = token
        
        if tag == "Adj":
            adj_tok = token
        
        if tag == "Verb":
            verb_tok = token
    
    for a, b, c in zip(noun_tok, adj_tok, verb_tok):
        s = a + b + c
        tokens.append(s)
    
    print(len(tokens))
    
    group['token'] = tokens
# Out:
# A --------------------
# 100%|██████████████████████████████████████████████████████████████| 94181/94181 [03:00<00:00, 522.99it/s]
# 100%|█████████████████████████████████████████████████████████████| 94181/94181 [00:21<00:00, 4458.23it/s]
# 100%|███████████████████████████████████████████████████████████| 94181/94181 [00:00<00:00, 433560.32it/s]
# 100%|██████████████████████████████████████████████████████████████| 94181/94181 [03:00<00:00, 520.62it/s]
# 100%|████████████████████████████████████████████████████████████| 94181/94181 [00:06<00:00, 15345.35it/s]
# 100%|███████████████████████████████████████████████████████████| 94181/94181 [00:00<00:00, 297290.64it/s]
# 100%|██████████████████████████████████████████████████████████████| 94181/94181 [03:01<00:00, 519.63it/s]
# 100%|█████████████████████████████████████████████████████████████| 94181/94181 [00:12<00:00, 7332.36it/s]
# 100%|███████████████████████████████████████████████████████████| 94181/94181 [00:00<00:00, 490415.43it/s]
# 94181
# B --------------------
# C:\ProgramData\Anaconda3\envs\pytorch-gpu-V\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100%|██████████████████████████████████████████████████████████████| 52811/52811 [01:45<00:00, 500.44it/s]
# 100%|█████████████████████████████████████████████████████████████| 52811/52811 [00:11<00:00, 4564.00it/s]
# 100%|███████████████████████████████████████████████████████████| 52811/52811 [00:00<00:00, 382601.78it/s]
# 100%|██████████████████████████████████████████████████████████████| 52811/52811 [01:45<00:00, 498.88it/s]
# 100%|████████████████████████████████████████████████████████████| 52811/52811 [00:03<00:00, 14919.20it/s]
# 100%|███████████████████████████████████████████████████████████| 52811/52811 [00:00<00:00, 502852.20it/s]
# 100%|██████████████████████████████████████████████████████████████| 52811/52811 [01:45<00:00, 499.49it/s]
# 100%|█████████████████████████████████████████████████████████████| 52811/52811 [00:06<00:00, 7588.73it/s]
# 100%|███████████████████████████████████████████████████████████| 52811/52811 [00:00<00:00, 165514.24it/s]
# 52811
# C --------------------
# 100%|████████████████████████████████████████████████████████████| 197473/197473 [06:36<00:00, 497.85it/s]
# 100%|███████████████████████████████████████████████████████████| 197473/197473 [00:42<00:00, 4694.34it/s]
# 100%|█████████████████████████████████████████████████████████| 197473/197473 [00:00<00:00, 280836.78it/s]
# 100%|████████████████████████████████████████████████████████████| 197473/197473 [06:36<00:00, 498.24it/s]
# 100%|██████████████████████████████████████████████████████████| 197473/197473 [00:11<00:00, 17818.26it/s]
# 100%|█████████████████████████████████████████████████████████| 197473/197473 [00:00<00:00, 565698.11it/s]
# 100%|████████████████████████████████████████████████████████████| 197473/197473 [06:34<00:00, 500.42it/s]
# 100%|███████████████████████████████████████████████████████████| 197473/197473 [00:25<00:00, 7839.12it/s]
# 100%|█████████████████████████████████████████████████████████| 197473/197473 [00:00<00:00, 287376.77it/s]
# 197473

# %%
def word_contained(tokens, word):
    
    for token in tokens:
        if token == word:
            return True
    return False

# %%
def get_full_text_with_word(group, word):
    return group[group["token"].progress_apply(word_contained, args=(word,))]

# %%
with open('groupA.pickle', 'wb') as f:
    pickle.dump(groupA, f, pickle.HIGHEST_PROTOCOL)

with open('groupB.pickle', 'wb') as f:
    pickle.dump(groupB, f, pickle.HIGHEST_PROTOCOL)

with open('groupC.pickle', 'wb') as f:
    pickle.dump(groupC, f, pickle.HIGHEST_PROTOCOL)

# %%
# with open('groupA.pickle', 'rb') as f:
#     groupA = pickle.load(f)
    
# with open('groupB.pickle', 'rb') as f:
#     groupB = pickle.load(f)
    
# with open('groupC.pickle', 'rb') as f:
#     groupC = pickle.load(f)

# %%
get_full_text_with_word(groupB, "channel")
# Out:
# 100%|███████████████████████████████████████████████████████████| 52811/52811 [00:00<00:00,
# 84987 2019-05-15 00:50:00  Found you channel about a year ago used to sub...
# 85046 2019-05-14 23:08:37  I found you channel back in 2012 been with ya ...
# 85066 2019-05-14 22:34:36     I found you channel from walking dead seaaon 1
# 85095 2019-05-14 21:47:25  I found you channel from mw3 when I got stuck ...
# 85130 2019-05-14 20:52:01  Can't remember exactly when I found you channe...
# 85505 2019-05-14 14:12:27                   Found you channel on dying light
# 85511 2019-05-14 14:08:06  Bro I want to get this game so bad and I found...
# 85524 2019-05-14 14:00:34  I found youre channel back in 2012 during the ...
# 85552 2019-05-14 13:38:02  I found you channel looking for gameplay of de...
# 85568 2019-05-14 13:29:15  Found you channel when Far Cry 3 came out.  Be...
# 85608 2019-05-14 12:59:48  I found you channel when you played the last o...
# 85800 2019-05-14 10:49:21  I have been watching you channel for about a y...
# 85911 2019-05-14 09:10:14  Found yur channel 2 years ago best gaming channel
# 86109 2019-05-14 06:45:27  I found you channel back on your Far Cry 3 videos
# 86247 2019-05-14 05:40:28  I found you're channel back at silent hill dow...
# 86286 2019-05-14 05:17:08                      I found yours channel on 2015
# 86419 2019-05-14 04:27:35  Found channel back at The Last of Us.  PS4 ple...
# 86583 2019-05-14 03:38:41  Found you channel back in 2014 love your work ...
# 86719 2019-05-14 03:10:01  Brad I would love to win please your absolutel...
# 87050 2019-05-14 02:34:41  I found it channel ab 2 years. Ago and it was ...
#
#        datediff                                              token
# 2806          1  [found, channel, remember, talking, having, ge...
# 3484          0                      [Creed, love, found, channel]
# 3930          0          [remember, found, channel, were, playing]
# 84195         5                      [found, channel, lovve, want]
# 84275         4                  [found, channel, did, made, fall]
# 84331         4                        [found, channel, love, get]
# 84386         3                               [channel, got, Send]
# 84525         2                                   [found, channel]
# 84616         1    [’m, watched, channel, wa, ’ve, been, watching]
# 84640         1                                          [channel]
# 84764         1  [found, channel, have, watched, loved, content...
# 84765         1  [channel, loved, video, remember, playing, cam...
# 84858         1                  [started, watching, 're, channel]
# 84882         1  [found, channel, wa, looking, loved, have, wat...
# 84987         1                            [channel, used, subbed]
# 85046         0                             [found, channel, been]
# 85066         0                          [found, channel, walking]
# 85095         0  [found, channel, got, stuck, wanted, see, happ...
# 85130         0  [remember, found, channel, have, been, watchin...
# 85505         0                                   [channel, dying]
# 85511         0  [want, get, found, channel, played, rage, play...
# 85524         0      [found, re, channel, completed, am, like, do]
# 85552         0                          [found, channel, looking]
# 85568         0                            [channel, came, Loving]
# 85608         0  [found, channel, played, had, did, have, play,...
# 85800         0                    [have, been, watching, channel]
# 85911         0                                          [channel]
# 86109         0                                   [found, channel]
# 86247         0                              [found, 're, channel]
# 86286         0                                   [found, channel]
# 86419         0                                          [channel]
# 86583         0                              [channel, love, keep]
# 86719         0                [love, win, please, found, channel]
# 87050         0                               [found, channel, wa]

# %% [markdown]
# # Counter

# %%
result = {}
for group, groupName in zip((groupA, groupB, groupC), ("A", "B", "C")):
    print(groupName, "--------------------")
# 100%|█████████████████████████████████████████████████████████| 197473/197473 [00:00<00:00, 445663.60it/s]

# %%
# with open('pos_tag_result.pickle', 'wb') as f:
#     pickle.dump(result, f, pickle.HIGHEST_PROTOCOL)

# %%
with open('pos_tag_result.pickle', 'rb') as f:
    result = pickle.load(f)

# %%
result.keys()
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
result['A'].keys()
# Out:
# dict_keys(['Noun', 'Adj', 'Verb'])

# %% [markdown]
# # Noun

# %%
for word, count in result['A']['Noun'].most_common(10):
    print(word, count)
# Out:
# game 31005
# video 5024
# time 4121
# story 3416
# character 3269
# person 3039
# thing 2325
# trailer 2265
# way 2094
# ad 2045

# %%
len(result['A']['Noun'].keys())
# Out:
# 34914

# %%
total_noun_cnt = sum(result['A']['Noun'].values())

# %%
total_top_100 =0
for _, count in result['A']['Noun'].most_common(100):
    total_top_100 += count

# %%
total_top_100
# Out:
# 150514

# %%
def get_top_100_percent(group, pos, verbose=True):
    total_top_100 =0
    for word, count in result[group][pos].most_common(100):
        total_top_100 += count
    
    for word, count in result[group][pos].most_common(100):
        if verbose:
            print(word, "%.2f" % (count/total_top_100*100), count)
    
    return total_top_100

# %% [markdown]
# # test

# %%
shared_pos = ( set([word for word, _ in result["A"]["Noun"].most_common(100)]) 
    & set([word for word, _ in result["B"]["Noun"].most_common(100)])
    & set([word for word, _ in result["C"]["Noun"].most_common(100)]))

# %%
a = {}
for group in ["A", "B", "C"]:
    for word, count in result[group]["Noun"].most_common(100):
        if word in shared_pos:
            if word not in a:
                a[word] = [count]
            else:
                a[word].append(count)

# %%
def shared_word_percent(pos):
    
    shared_pos = ( set([word for word, _ in result["A"][pos].most_common(100)]) 
    & set([word for word, _ in result["B"][pos].most_common(100)])
    & set([word for word, _ in result["C"][pos].most_common(100)]))
    
    a = {}
    for group in ["A", "B", "C"]:
        total_top_100 =0
        for word, count in result[group][pos].most_common(100):
            total_top_100 += count
        
        for word, count in result[group][pos].most_common(100):
            if word in shared_pos:
                percent = count/total_top_100
                if word not in a:
                    a[word] = [percent*100]
                else:
                    a[word].append(percent*100)
    return a

# %% [markdown]
# ## Entropy

# %%
from scipy.stats import entropy

# %%
def word_entropy(pos):
    a = [x for x,y in result["A"][pos].most_common()]
    b = [x for x,y in result["B"][pos].most_common()]
    c = [x for x,y in result["C"][pos].most_common()]
    
    all_word = set(a+b+c)
    
    for word in all_word:
    
        a_cnt = result["A"][pos][word]
        b_cnt = result["B"][pos][word]
        c_cnt = result["C"][pos][word]

        ent = entropy([a_cnt, b_cnt, c_cnt], base=3)

        if (0.01 < ent < 0.5) and sum([a_cnt, b_cnt, c_cnt]) > 100:
            print(word, a_cnt, b_cnt, c_cnt, ent)

# %%
word_entropy("Verb")
# Out:
# fear 12 8 114 0.47501919498779804
# Sean 0 1 282 0.02136867968413015
# mark 7 1 361 0.1025626174562346
# tracing 3 7 233 0.1790690149425795
# helped 70 93 957 0.4681456036127052
